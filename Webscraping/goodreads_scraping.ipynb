# %%
from urllib.request import urlopen
from requests import get
from bs4 import BeautifulSoup
from pathlib import Path
from time import sleep
from time import time
from random import randint
from IPython.core.display import clear_output
import pandas as pd
import re

# %%
namelist=[]
authorlist=[]
ratinglist=[]
numofratingslist=[]
publisedyearlist=[]
imglinklist=[]
bookgenres = []

headers = {"Accept-Language": "en-US, en;q=0.5"}

genres = ["biography","contemporary","crime","fiction","fantasy","mystery","romance","thriller"]
pages = [i.__str__() for i in range(1,5)]


start_time = time()
requests = 0

#For every genre in genres list
for genre in genres:
    
    #For every page from 1 to 5
    for page in pages:
        
        response = get('https://www.goodreads.com/shelf/show/'+ genre +'?page='+ page, headers = headers)
       
        # Pause the loop
        sleep(randint(8,15))

        # Monitor the requests
        requests += 1
        elapsed_time = time() - start_time
        #print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
        clear_output(wait = True)

        # Throw a warning for non-200 status codes
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(requests, response.status_code))

        # Break the loop if the number of requests is greater than expected
        if requests > 72:
            warn('Number of requests was greater than expected.')  
            break 

        
        bs=BeautifulSoup(response.text,'html.parser')
       
        bookscontainer = bs.find_all('div',class_= 'elementList')

        for book in bookscontainer:

            if book.find('a',class_='bookTitle') is not None:  
                #To retrieve the book names
                name = book.find('a',class_='bookTitle').contents[0]
                name = re.sub("[\(\[].*?[\)\]]", "", name)
                namelist.append(name)
                bookgenres.append(genre)
                #print(name)

            if book.find('a',class_='authorName') is not None:
                #To retrieve the author of the book
                author = book.find('a',class_='authorName').span.text
                authorlist.append(author)
                #print(author)

            if book.find('span',class_='greyText smallText') is not None:
                #To retrieve ratings & Year of publication
                arr = book.find('span',class_='greyText smallText').text.split(" —\n ")
                rating = arr[0][-4:]
                ratinglist.append(float(rating))
                
                ratingnum = re.sub("[^\d]","",arr[1])
                numofratingslist.append(ratingnum)
               
                
                year = re.sub("[^\d]","",arr[2])
                print(year)
                publisedyearlist.append(year)
               
        
                #print(rating," ",ratingnum," ",year)

            if book.find('a',class_='leftAlignedImage') is not None:
                imglink = book.find('a',class_='leftAlignedImage').img['src']
                imglinklist.append(imglink)
                #print(imglink)
            #print(name," ",author," ",ratingnum," ",rating)
# Out:
# 2003
# 2015
# 2012
# 2005
# 2000
# 2006
# 2007
# 2009
# 2006
# 2013
# 2001
# 2009
# 1998
# 1988
# 2011
# 1990
# 1980
# 2018
# 1997
# 1981
# 1977
# 2016
# 2016
# 2014
# 2016
# 2014
# 1984
# 2003
# 1939
# 2017
# 2017
# 1987
# 1989
# 2007
# 2015
# 1991
# 2016
# 1998
# 1992
# 1993
# 2015
# 1995
# 2014
# 1986
# 1993
# 1999
# 2017
# 1987
# 2013
# 2013

# %%
book_ratings = pd.DataFrame({'Book': namelist,
                              'Author': authorlist,
                              'Genre' : bookgenres,
                              'Year Of publication': publisedyearlist,
                              'Average rating': ratinglist,
                              'Number of ratings': numofratingslist,
                              'BookCover Image': imglinklist})
print(book_ratings.info())
print(book_ratings)
output_csvfile = 'goodreads_ratings.csv'
output_csvdir = Path('csv_output')
output_csvdir.mkdir(parents=True, exist_ok=True)

output_jsonfile = 'goodreads_ratings.json'
output_jsondir = Path('json_output')
output_jsondir.mkdir(parents=True, exist_ok=True)

book_ratings.to_csv(output_csvdir / output_csvfile)
book_ratings.to_json(output_jsondir / output_jsonfile,orient="records",date_format="iso")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 7 columns):
# Book                   1600 non-null object
# Author                 1600 non-null object
# Genre                  1600 non-null object
# Year Of publication    1600 non-null object
# Average rating         1600 non-null float64
# Number of ratings      1600 non-null object
# BookCover Image        1600 non-null object
# dtypes: float64(1), object(6)
# memory usage: 87.6+ KB
# None
#                                                    Book                Author  \
# 0                                           Steve Jobs        Walter Isaacson
# 1                            The Diary of a Young Girl             Anne Frank
# 2     Unbroken: A World War II Story of Survival, Re...     Laura Hillenbrand
# 3                                           John Adams       David McCullough
# 4                                           Bossypants               Tina Fey
# 5                 The Immortal Life of Henrietta Lacks         Rebecca Skloot
# 6                                   Alexander Hamilton            Ron Chernow
# 7                      Einstein: His Life and Universe        Walter Isaacson
# 8                                        Into the Wild           Jon Krakauer
# 9     Elon Musk: Tesla, SpaceX, and the Quest for a ...          Ashlee Vance
# 10    I Am Malala: The Story of the Girl Who Stood U...      Malala Yousafzai
# 11                      The Autobiography of Malcolm X              Malcolm X
# 12                 Benjamin Franklin: An American Life        Walter Isaacson
# 13                                               Night            Elie Wiesel
# 14    "Surely You're Joking, Mr. Feynman!": Adventur...       Richard Feynman
# 15                                   Cleopatra: A Life           Stacy Schiff
# 16                                          Yes Please            Amy Poehler
# 17                                    The Glass Castle        Jeannette Walls
# 18    Team of Rivals: The Political Genius of Abraha...  Doris Kearns Goodwin
# 19                                      Angela's Ashes          Frank McCourt
# 20            Catherine the Great: Portrait of a Woman       Robert K. Massie
# 21    Born a Crime: Stories From a South African Chi...           Trevor Noah
# 22            Bonhoeffer: Pastor, Martyr, Prophet, Spy           Eric Metaxas
# 23              The Autobiography of Benjamin Franklin      Benjamin Franklin
# 24                      The Rise of Theodore Roosevelt          Edmund Morris
# 25                     I Know Why the Caged Bird Sings           Maya Angelou
# 26                                  Washington: A Life            Ron Chernow
# 27    Wild: From Lost to Found on the Pacific Crest ...        Cheryl Strayed
# 28                             When Breath Becomes Air         Paul Kalanithi
# 29    The Hiding Place: The Triumphant True Story of...       Corrie ten Boom
# ...                                                 ...                   ...
# 1570                                       The Shining           Stephen King
# 1571                                       Dark Matter           Blake Crouch
# 1572                             The Woman in Cabin 10              Ruth Ware
# 1573                                      Mr. Mercedes           Stephen King
# 1574                               Behind Closed Doors             B.A. Paris
# 1575                                               You        Caroline Kepnes
# 1576                          The Hunt for Red October             Tom Clancy
# 1577                                    Shutter Island          Dennis Lehane
# 1578                          And Then There Were None        Agatha Christie
# 1579                                    Into the Water          Paula Hawkins
# 1580                                            Origin              Dan Brown
# 1581                                            Misery           Stephen King
# 1582                                    A Time to Kill           John Grisham
# 1583                                      In the Woods            Tana French
# 1584                              In a Dark, Dark Wood              Ruth Ware
# 1585                                          The Firm           John Grisham
# 1586                              The Couple Next Door           Shari Lapena
# 1587                                        Die Trying              Lee Child
# 1588                                 The Pelican Brief           John Grisham
# 1589                               Along Came a Spider        James Patterson
# 1590                                      Pretty Girls        Karin Slaughter
# 1591                                             Relic        Douglas Preston
# 1592         Assuming Names: A Con Artist's Masquerade         Tanya Thompson
# 1593                                                It           Stephen King
# 1594                                        The Client           John Grisham
# 1595                                          Hannibal        Thomas   Harris
# 1596                                       Final Girls            Riley Sager
# 1597                                     Patriot Games             Tom Clancy
# 1598                              The Cuckoo's Calling       Robert Galbraith
# 1599                                      I Am Pilgrim            Terry Hayes
#
#           Genre Year Of publication  Average rating Number of ratings  \
# 0     biography                2011            4.12            768288
# 1     biography                1947            4.12           2342796
# 2     biography                2010            4.38            638867
# 3     biography                2001            4.05            263746
# 4     biography                2011            3.95            723079
# 5     biography                2010            4.05            490212
# 6     biography                2004            4.24             85786
# 7     biography                2007            4.09             98148
# 8     biography                1996            3.97            765994
# 9     biography                2015            4.23            148658
# 10    biography                2012            4.10            316498
# 11    biography                1965            4.30            160200
# 12    biography                2003            3.98             93932
# 13    biography                1958            4.31            841796
# 14    biography                1985            4.28            124566
# 15    biography                2010            3.64             83912
# 16    biography                2014            3.82            353339
# 17    biography                2005            4.26            765407
# 18    biography                2005            4.28            128954
# 19    biography                1996            4.09            477067
# 20    biography                2011            3.91             84290
# 21    biography                2016            4.45            180980
# 22    biography                2009            4.22             46723
# 23    biography                1791            3.82             56398
# 24    biography                1979            4.24             33911
# 25    biography                1969            4.22            337964
# 26    biography                2010            4.07             41723
# 27    biography                2012            3.99            510584
# 28    biography                2016            4.34            287468
# 29    biography                1971            4.41            219466
# ...         ...                 ...             ...               ...
# 1570   thriller                1977            4.20            943792
# 1571   thriller                2016            4.10            159605
# 1572   thriller                2016            3.68            243603
# 1573   thriller                2014            3.95            187926
# 1574   thriller                2016            3.95            203041
# 1575   thriller                2014            3.87             78501
# 1576   thriller                1984            4.05            305463
# 1577   thriller                2003            4.09            138821
# 1578   thriller                1939            4.25            609131
# 1579   thriller                2017            3.55            187960
# 1580   thriller                2017            3.85            178928
# 1581   thriller                1987            4.14            413234
# 1582   thriller                1989            4.05            652187
# 1583   thriller                2007            3.76            246982
# 1584   thriller                2015            3.68            150457
# 1585   thriller                1991            4.00            517877
# 1586   thriller                2016            3.77            207058
# 1587   thriller                1998            4.02             87234
# 1588   thriller                1992            3.98            327373
# 1589   thriller                1993            4.10            358198
# 1590   thriller                2015            3.99            126929
# 1591   thriller                1995            4.02             83224
# 1592   thriller                2014            3.51             13034
# 1593   thriller                1986            4.22            640493
# 1594   thriller                1993            3.99            355067
# 1595   thriller                1999            3.75             72445
# 1596   thriller                2017            3.80             38802
# 1597   thriller                1987            4.13            168547
# 1598   thriller                2013            3.85            410800
# 1599   thriller                2013            4.25             94546
#
#                                         BookCover Image
# 0     https://images.gr-assets.com/books/1511288482s...
# 1     https://images.gr-assets.com/books/1537075718s...
# 2     https://images.gr-assets.com/books/1327861115s...
# 3     https://images.gr-assets.com/books/1478144278s...
# 4     https://images.gr-assets.com/books/1481509554s...
# 5     https://images.gr-assets.com/books/1327878144s...
# 6     https://images.gr-assets.com/books/1436131915s...
# 7     https://images.gr-assets.com/books/1328011405s...
# 8     https://images.gr-assets.com/books/1403173986s...
# 9     https://images.gr-assets.com/books/1518291452s...
# 10    https://images.gr-assets.com/books/1375414895s...
# 11    https://images.gr-assets.com/books/1434682864s...
# 12    https://images.gr-assets.com/books/1397772877s...
# 13    https://images.gr-assets.com/books/1473495285s...
# 14    https://images.gr-assets.com/books/1504936953s...
# 15    https://images.gr-assets.com/books/1294098301s...
# 16    https://images.gr-assets.com/books/1402815435s...
# 17    https://images.gr-assets.com/books/1523542886s...
# 18    https://images.gr-assets.com/books/1347278868s...
# 19    https://images.gr-assets.com/books/1348317139s...
# 20    https://images.gr-assets.com/books/1403395276s...
# 21    https://images.gr-assets.com/books/1473867911s...
# 22    https://images.gr-assets.com/books/1298218180s...
# 23    https://images.gr-assets.com/books/1428170518s...
# 24    https://images.gr-assets.com/books/1452010007s...
# 25    https://images.gr-assets.com/books/1327957927s...
# 26    https://images.gr-assets.com/books/1348969179s...
# 27    https://images.gr-assets.com/books/1453189881s...
# 28    https://images.gr-assets.com/books/1492677644s...
# 29    https://images.gr-assets.com/books/1320418824s...
# ...                                                 ...
# 1570  https://images.gr-assets.com/books/1353277730s...
# 1571  https://images.gr-assets.com/books/1472119680s...
# 1572  https://images.gr-assets.com/books/1465878007s...
# 1573  https://images.gr-assets.com/books/1468705326s...
# 1574  https://images.gr-assets.com/books/1458854462s...
# 1575  https://images.gr-assets.com/books/1549463282s...
# 1576  https://images.gr-assets.com/books/1281995542s...
# 1577  https://images.gr-assets.com/books/1329269081s...
# 1578  https://images.gr-assets.com/books/1391120695s...
# 1579  https://images.gr-assets.com/books/1494055413s...
# 1580  https://images.gr-assets.com/books/1507308545s...
# 1581  https://images.gr-assets.com/books/1270545451s...
# 1582  https://images.gr-assets.com/books/1390195915s...
# 1583  https://images.gr-assets.com/books/1538771792s...
# 1584  https://images.gr-assets.com/books/1523543089s...
# 1585  https://images.gr-assets.com/books/1418465200s...
# 1586  https://images.gr-assets.com/books/1471502242s...
# 1587  https://images.gr-assets.com/books/1377633008s...
# 1588  https://images.gr-assets.com/books/1389486877s...
# 1589  https://images.gr-assets.com/books/1388272560s...
# 1590  https://images.gr-assets.com/books/1432205734s...
# 1591  https://images.gr-assets.com/books/1389576748s...
# 1592  https://images.gr-assets.com/books/1394851829s...
# 1593  https://images.gr-assets.com/books/1334416842s...
# 1594  https://images.gr-assets.com/books/1388632222s...
# 1595  https://images.gr-assets.com/books/1327356556s...
# 1596  https://images.gr-assets.com/books/1496658340s...
# 1597  https://images.gr-assets.com/books/1328007145s...
# 1598  https://images.gr-assets.com/books/1540217136s...
# 1599  https://images.gr-assets.com/books/1403345411s...
#
# [1600 rows x 7 columns]
